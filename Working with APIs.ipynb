# %%
import requests
import pandas as pd

# %%
response = requests.get('https://api.github.com/events')
data = pd.DataFrame(response.json())
data.head()
# Out:
#             id               type  \
# 0  19687334448          PushEvent
# 1  19687334466          PushEvent
# 2  19687334477  IssueCommentEvent
# 3  19687334441  IssueCommentEvent
# 4  19687334451          PushEvent
#
#                                                actor  \
# 0  {'id': 12312, 'login': 'manton', 'display_logi...
# 1  {'id': 12629902, 'login': 'bobaguardian', 'dis...
# 2  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 3  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 4  {'id': 63135033, 'login': 'Vix4723', 'display_...
#
#                                                 repo  \
# 0  {'id': 285034321, 'name': 'manton/manton.org',...
# 1  {'id': 444960146, 'name': 'bobaguardian/tablet...
# 2  {'id': 336356162, 'name': 'Mnigos/school-quiz'...
# 3  {'id': 211970231, 'name': 'tilne/aws-parallelc...
# 4  {'id': 261254206, 'name': 'Vix4723/vix4723.git...
#
#                                              payload  public  \
# ...

# %%
response.json()
# Out:
# [{'id': '19687334448',
#   'type': 'PushEvent',
#   'actor': {'id': 12312,
#    'login': 'manton',
#    'display_login': 'manton',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/manton',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12312?'},
#   'repo': {'id': 285034321,
#    'name': 'manton/manton.org',
#    'url': 'https://api.github.com/repos/manton/manton.org'},
#   'payload': {'push_id': 8812099185,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '88ed9c85bb62ddb0497cffbfd40f1758c3ded6ba',
#    'before': '4cb41347fce112f5de2fa31490b28f750927bb39',
#    'commits': [{'sha': '88ed9c85bb62ddb0497cffbfd40f1758c3ded6ba',
#      'author': {'email': 'manton@me.com', 'name': 'Manton Reece'},
#      'message': 'Archiving from Micro.blog.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/manton/manton.org/commits/88ed9c85bb62ddb0497cffbfd40f1758c3ded6ba'}]},
#   'public': True,
# ...

# %%
data['actor']
# Out:
# 0     {'id': 12312, 'login': 'manton', 'display_logi...
# 1     {'id': 12629902, 'login': 'bobaguardian', 'dis...
# 2     {'id': 49699333, 'login': 'dependabot[bot]', '...
# 3     {'id': 49699333, 'login': 'dependabot[bot]', '...
# 4     {'id': 63135033, 'login': 'Vix4723', 'display_...
# 5     {'id': 10810283, 'login': 'direwolf-github', '...
# 6     {'id': 2093802, 'login': 'Anoncheg1', 'display...
# 7     {'id': 18230652, 'login': 'ToiletCommander', '...
# 8     {'id': 40918737, 'login': 'donaldsouza', 'disp...
# 9     {'id': 36464209, 'login': 'harryrconway', 'dis...
# 10    {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 11    {'id': 25763875, 'login': 'gadepall', 'display...
# 12    {'id': 94878145, 'login': 'AwalZaman', 'displa...
# 13    {'id': 35613825, 'login': 'vercel[bot]', 'disp...
# 14    {'id': 97132266, 'login': 'adamszabo76', 'disp...
# 15    {'id': 38668450, 'login': 'jacobtylerwalls', '...
# 16    {'id': 96052245, 'login': 'liiiib', 'display_l...
# ...

# %%
dict(data['actor'])
# Out:
# {0: {'id': 37245253,
#   'login': 'fazenecture',
#   'display_login': 'fazenecture',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/fazenecture',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/37245253?'},
#  1: {'id': 3010904,
#   'login': 'postamar',
#   'display_login': 'postamar',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/postamar',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3010904?'},
#  2: {'id': 97123285,
#   'login': 'brokjad',
#   'display_login': 'brokjad',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/brokjad',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/97123285?'},
#  3: {'id': 13698158,
#   'login': 'tqureshi-uog',
#   'display_login': 'tqureshi-uog',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tqureshi-uog',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/13698158?'},
#  4: {'id': 56795920,
#   'login': 'kitkovsky',
# ...

# %%
pd.DataFrame(dict(data['actor']))
# Out:
#                                                            0   \
# id                                                      12312
# login                                                  manton
# display_login                                          manton
# gravatar_id
# url                       https://api.github.com/users/manton
# avatar_url     https://avatars.githubusercontent.com/u/12312?
#
#                                                               1   \
# id                                                      12629902
# login                                               bobaguardian
# display_login                                       bobaguardian
# gravatar_id
# url                    https://api.github.com/users/bobaguardian
# avatar_url     https://avatars.githubusercontent.com/u/12629902?
#
#                                                               2   \
# id                                                      49699333
# ...

# %%
pd.DataFrame(dict(data['actor'])).transpose()
# Out:
#           id                login       display_login gravatar_id  \
# 0      12312               manton              manton
# 1   12629902         bobaguardian        bobaguardian
# 2   49699333      dependabot[bot]          dependabot
# 3   49699333      dependabot[bot]          dependabot
# 4   63135033              Vix4723             Vix4723
# 5   10810283      direwolf-github     direwolf-github
# 6    2093802            Anoncheg1           Anoncheg1
# 7   18230652      ToiletCommander     ToiletCommander
# 8   40918737          donaldsouza         donaldsouza
# 9   36464209         harryrconway        harryrconway
# 10  39814207            pull[bot]                pull
# 11  25763875             gadepall            gadepall
# 12  94878145            AwalZaman           AwalZaman
# 13  35613825          vercel[bot]              vercel
# 14  97132266          adamszabo76         adamszabo76
# 15  38668450      jacobtylerwalls     jacobtylerwalls
# ...

# %%
data.columns
# Out:
# Index(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at',
#        'org'],
#       dtype='object')

# %%
pd.DataFrame(dict(data['org'])).transpose()
# Out:
#           id            login gravatar_id  \
# 0        NaN              NaN         NaN
# 1        NaN              NaN         NaN
# 2        NaN              NaN         NaN
# 3        NaN              NaN         NaN
# 4        NaN              NaN         NaN
# 5        NaN              NaN         NaN
# 6        NaN              NaN         NaN
# 7   30064570  InteractivePlus
# 8        NaN              NaN         NaN
# 9        NaN              NaN         NaN
# 10       NaN              NaN         NaN
# 11       NaN              NaN         NaN
# 12       NaN              NaN         NaN
# 13  95895483       verses-xyz
# 14       NaN              NaN         NaN
# 15   5853935      cuthbertLab
# 16       NaN              NaN         NaN
# 17       NaN              NaN         NaN
# 18  31250830         msoe-sse
# 19       NaN              NaN         NaN
# 20       NaN              NaN         NaN
# 21  68126246             o3de
# 22  15652042         easylist
# ...

# %%
from pandas.io.json import json_normalize
response = requests.get('https://api.github.com/events')
results = response.json()
flattened_data = json_normalize(results)
flattened_data
# Out:
# <ipython-input-14-29141c6d7e4d>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#              id              type  public            created_at  actor.id  \
# 0   19687422295       CreateEvent    True  2022-01-12T00:29:58Z  18434479
# 1   19687422263         PushEvent    True  2022-01-12T00:29:58Z  82232510
# 2   19687422243         PushEvent    True  2022-01-12T00:29:58Z  91284012
# 3   19687422235         PushEvent    True  2022-01-12T00:29:58Z  47800892
# 4   19687422253         PushEvent    True  2022-01-12T00:29:58Z  56041445
# 5   19687422238       CreateEvent    True  2022-01-12T00:29:58Z  74343139
# 6   19687422246         PushEvent    True  2022-01-12T00:29:58Z  91858416
# 7   19687422240       IssuesEvent    True  2022-01-12T00:29:58Z   1075694
# 8   19687422213         PushEvent    True  2022-01-12T00:29:58Z  29139614
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
response = requests.get('https://api.github.com/users/haggarw3/repos')
datah = pd.DataFrame(response.json())

# %%
datah
# Out:
#            id                           node_id  \
# 0   381426739  MDEwOlJlcG9zaXRvcnkzODE0MjY3Mzk=
# 1   255509246  MDEwOlJlcG9zaXRvcnkyNTU1MDkyNDY=
# 2   404606377  MDEwOlJlcG9zaXRvcnk0MDQ2MDYzNzc=
# 3   328973322  MDEwOlJlcG9zaXRvcnkzMjg5NzMzMjI=
# 4   316876517  MDEwOlJlcG9zaXRvcnkzMTY4NzY1MTc=
# 5   383693721  MDEwOlJlcG9zaXRvcnkzODM2OTM3MjE=
# 6   235374982  MDEwOlJlcG9zaXRvcnkyMzUzNzQ5ODI=
# 7   216898113  MDEwOlJlcG9zaXRvcnkyMTY4OTgxMTM=
# 8   446618306                      R_kgDOGp7awg
# 9   404423374  MDEwOlJlcG9zaXRvcnk0MDQ0MjMzNzQ=
# 10  327898193  MDEwOlJlcG9zaXRvcnkzMjc4OTgxOTM=
# 11  276280680  MDEwOlJlcG9zaXRvcnkyNzYyODA2ODA=
# 12  222960697  MDEwOlJlcG9zaXRvcnkyMjI5NjA2OTc=
# 13  223261075  MDEwOlJlcG9zaXRvcnkyMjMyNjEwNzU=
# 14  188448800  MDEwOlJlcG9zaXRvcnkxODg0NDg4MDA=
# 15  216897595  MDEwOlJlcG9zaXRvcnkyMTY4OTc1OTU=
# 16  327250992  MDEwOlJlcG9zaXRvcnkzMjcyNTA5OTI=
# 17  327730430  MDEwOlJlcG9zaXRvcnkzMjc3MzA0MzA=
# ...

# %%
pd.DataFrame(dict(datah['owner'])).T
# Out:
#        login        id               node_id  \
# 0   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 1   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 2   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 3   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 4   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 5   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 6   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 7   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 8   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 9   haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 10  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 11  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 12  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 13  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 14  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 15  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 16  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 17  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 18  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# 19  haggarw3  22273533  MDQ6VXNlcjIyMjczNTMz
# ...

# %%
response = requests.get('https://api.github.com/users/haggarw3/repos')
results = response.json()
flattened_data = json_normalize(results)
flattened_data
# Out:
# <ipython-input-17-0db9bb6a195d>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#            id                           node_id  \
# 0   381426739  MDEwOlJlcG9zaXRvcnkzODE0MjY3Mzk=
# 1   255509246  MDEwOlJlcG9zaXRvcnkyNTU1MDkyNDY=
# 2   404606377  MDEwOlJlcG9zaXRvcnk0MDQ2MDYzNzc=
# 3   328973322  MDEwOlJlcG9zaXRvcnkzMjg5NzMzMjI=
# 4   316876517  MDEwOlJlcG9zaXRvcnkzMTY4NzY1MTc=
# 5   383693721  MDEwOlJlcG9zaXRvcnkzODM2OTM3MjE=
# 6   235374982  MDEwOlJlcG9zaXRvcnkyMzUzNzQ5ODI=
# 7   216898113  MDEwOlJlcG9zaXRvcnkyMTY4OTgxMTM=
# 8   446618306                      R_kgDOGp7awg
# 9   404423374  MDEwOlJlcG9zaXRvcnk0MDQ0MjMzNzQ=
# 10  327898193  MDEwOlJlcG9zaXRvcnkzMjc4OTgxOTM=
# 11  276280680  MDEwOlJlcG9zaXRvcnkyNzYyODA2ODA=
# 12  222960697  MDEwOlJlcG9zaXRvcnkyMjI5NjA2OTc=
# 13  223261075  MDEwOlJlcG9zaXRvcnkyMjMyNjEwNzU=
# 14  188448800  MDEwOlJlcG9zaXRvcnkxODg0NDg4MDA=
# ...

# %%
requests.get('https://api.github.com/users/haggarw3/repos').content
# Out:
# b'[{"id":381426739,"node_id":"MDEwOlJlcG9zaXRvcnkzODE0MjY3Mzk=","name":"20778-Analyzing-Data-with-Power-BI","full_name":"haggarw3/20778-Analyzing-Data-with-Power-BI","private":false,"owner":{"login":"haggarw3","id":22273533,"node_id":"MDQ6VXNlcjIyMjczNTMz","avatar_url":"https://avatars.githubusercontent.com/u/22273533?v=4","gravatar_id":"","url":"https://api.github.com/users/haggarw3","html_url":"https://github.com/haggarw3","followers_url":"https://api.github.com/users/haggarw3/followers","following_url":"https://api.github.com/users/haggarw3/following{/other_user}","gists_url":"https://api.github.com/users/haggarw3/gists{/gist_id}","starred_url":"https://api.github.com/users/haggarw3/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/haggarw3/subscriptions","organizations_url":"https://api.github.com/users/haggarw3/orgs","repos_url":"https://api.github.com/users/haggarw3/repos","events_url":"https://api.github.com/users/haggarw3/events{/privacy}","received_ev
# ...

# %%
import requests
import json
import getpass

username = 'haggarw3'
token = getpass.getpass(prompt='Token: ', stream=None)

# Create a re-usable session object with the user creds in-built
gh_session = requests.Session()
gh_session.auth = (username, token)
# Out:
# Token: ········

# %%
json.loads(gh_session.get('https://api.github.com/users/haggarw3/repos').text)
# Out:
# [{'id': 381426739,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODE0MjY3Mzk=',
#   'name': '20778-Analyzing-Data-with-Power-BI',
#   'full_name': 'haggarw3/20778-Analyzing-Data-with-Power-BI',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
# ...

# %%
pd.DataFrame(gh_session.get('https://api.github.com/users/haggarw3/repos').json())
# Out:
#            id                           node_id  \
# 0   381426739  MDEwOlJlcG9zaXRvcnkzODE0MjY3Mzk=
# 1   255509246  MDEwOlJlcG9zaXRvcnkyNTU1MDkyNDY=
# 2   404606377  MDEwOlJlcG9zaXRvcnk0MDQ2MDYzNzc=
# 3   328973322  MDEwOlJlcG9zaXRvcnkzMjg5NzMzMjI=
# 4   316876517  MDEwOlJlcG9zaXRvcnkzMTY4NzY1MTc=
# 5   383693721  MDEwOlJlcG9zaXRvcnkzODM2OTM3MjE=
# 6   235374982  MDEwOlJlcG9zaXRvcnkyMzUzNzQ5ODI=
# 7   216898113  MDEwOlJlcG9zaXRvcnkyMTY4OTgxMTM=
# 8   446618306                      R_kgDOGp7awg
# 9   404423374  MDEwOlJlcG9zaXRvcnk0MDQ0MjMzNzQ=
# 10  327898193  MDEwOlJlcG9zaXRvcnkzMjc4OTgxOTM=
# 11  276280680  MDEwOlJlcG9zaXRvcnkyNzYyODA2ODA=
# 12  222960697  MDEwOlJlcG9zaXRvcnkyMjI5NjA2OTc=
# 13  223261075  MDEwOlJlcG9zaXRvcnkyMjMyNjEwNzU=
# 14  188448800  MDEwOlJlcG9zaXRvcnkxODg0NDg4MDA=
# 15  216897595  MDEwOlJlcG9zaXRvcnkyMTY4OTc1OTU=
# 16  327250992  MDEwOlJlcG9zaXRvcnkzMjcyNTA5OTI=
# 17  327730430  MDEwOlJlcG9zaXRvcnkzMjc3MzA0MzA=
# ...

# %%
json.loads(gh_session.get('https://api.github.com/user').text)
# Out:
# {'login': 'KaylaBolden',
#  'id': 89061371,
#  'node_id': 'MDQ6VXNlcjg5MDYxMzcx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/89061371?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/KaylaBolden',
#  'html_url': 'https://github.com/KaylaBolden',
#  'followers_url': 'https://api.github.com/users/KaylaBolden/followers',
#  'following_url': 'https://api.github.com/users/KaylaBolden/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/KaylaBolden/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/KaylaBolden/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/KaylaBolden/subscriptions',
#  'organizations_url': 'https://api.github.com/users/KaylaBolden/orgs',
#  'repos_url': 'https://api.github.com/users/KaylaBolden/repos',
#  'events_url': 'https://api.github.com/users/KaylaBolden/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/KaylaBolden/received_events',
# ...

# %%
pd.DataFrame(gh_session.get('https://api.github.com/repos/KaylaBolden/lab-web-scraping-multiple-pages/contributors').json())
# Out:
#          login        id               node_id  \
# 0  KaylaBolden  89061371  MDQ6VXNlcjg5MDYxMzcx
# 1   sandrabosk  25275745  MDQ6VXNlcjI1Mjc1NzQ1
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/890613...
# 1  https://avatars.githubusercontent.com/u/252757...
#
#                                         url                        html_url  \
# 0  https://api.github.com/users/KaylaBolden  https://github.com/KaylaBolden
# 1   https://api.github.com/users/sandrabosk   https://github.com/sandrabosk
#
#                                        followers_url  \
# 0  https://api.github.com/users/KaylaBolden/follo...
# 1  https://api.github.com/users/sandrabosk/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/KaylaBolden/follo...
# 1  https://api.github.com/users/sandrabosk/follow...
#
#                                            gists_url  \
# ...
